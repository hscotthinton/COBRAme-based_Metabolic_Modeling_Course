# %% [markdown]
# # Aerobic Dynamic Flux Balance Analysis (dFBA) using COBRAme

# %%
import cobra
#from cobra.io import load_model
import numpy as np
#from tqdm import tqdm
from math import exp
from contextlib import suppress

from scipy.integrate import solve_ivp

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/solvers/__init__.py:63: UserWarning: No LP solvers found
#   warn("No LP solvers found")
# /usr/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/io/sbml3.py:24: UserWarning: Install lxml for faster SBML I/O
#   warn("Install lxml for faster SBML I/O")
# /usr/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/io/__init__.py:12: UserWarning: cobra.io.sbml requires libsbml
#   warn("cobra.io.sbml requires libsbml")

# %%
from __future__ import print_function, division, absolute_import

# python imports
import re
from os.path import join
from collections import defaultdict
import pickle
import pandas as pd

# third party imports
import pandas
import tabulate
import cobra
pd.set_option('display.max_columns', 100)
pd.set_option('display.width',100)
pd.set_option('display.max_colwidth',300)

# ECOLIme
import ecolime
from ecolime import (transcription, translation, flat_files, generics, formulas, compartments)

# COBRAme
import cobrame
from cobrame.util import building, mu, me_model_interface
#from cobrame.io.json import save_json_me_model, save_reduced_json_me_model

# %% [markdown]
# Create or load a cobrapy model. Here, we use the 'textbook' e-coli core model.

# %%
with open('iJL1678b.pickle', 'rb') as f:
    model = pickle.load(f)

#model.reactions.EX_glc__D_e.lower_bound = -10
model.reactions.EX_o2_e.lower_bound = -20
model.reactions.EX_ac_e.lower_bound = -10
model.reactions.EX_for_e.lower_bound = -10

# %%
def solve_me_model(model, max_mu, precision=1e-6, min_mu=0, using_soplex=False,
                  compiled_expressions=None):
    if using_soplex:
        from cobrame.solve.algorithms import binary_search
        binary_search(model, min_mu=min_mu, max_mu=max_mu, debug=True, mu_accuracy=precision,
                      compiled_expressions=compiled_expressions)
    else:
        from qminospy.me1 import ME_NLP1
        # The object containing solveME methods--composite that uses a ME model object 
        me_nlp = ME_NLP1(model, growth_key='mu')
        # Use bisection for now (until the NLP formulation is worked out)
        muopt, hs, xopt, cache = me_nlp.bisectmu(precision=precision, mumax=max_mu)
        model.solution.f = model.solution.x_dict['biomass_dilution']
        
def show_escher_map(model, solution=None):
    import escher
    view = escher.Builder("iJO1366.Central metabolism")
    view.reaction_data = model.get_metabolic_flux(solution=solution)
    return view

# %%
# Initial Constants
biomass_0 = 0.035 # Initial biomass
biomass_t = biomass_0
#delta_t = 0.25
time_total = 8 # Hours
samples = 16 # Total number of samples
delta_t = time_total/samples
biomass = []
mu_results = []
solution_results = []
biomass.append(biomass_0)

# Initialize glucose variables
glc_initial_concentration = 10
glc_past_concentration = glc_initial_concentration
glucose_concentration = []
glucose_concentration.append(glc_initial_concentration)

# Initialize acetate variables
ac_initial_concentration = 0
ac_past_concentration = ac_initial_concentration
acetate_concentration = []
acetate_concentration.append(ac_initial_concentration)

# Initialize formate variables
for_initial_concentration = 0
for_past_concentration = for_initial_concentration
formate_concentration = []
formate_concentration.append(for_initial_concentration)

# Set metabolite t0 concentrations
glc_concentration = glc_initial_concentration
ac_concentration = ac_initial_concentration
for_concentration = for_initial_concentration

# Determine timesteps
time = [x*delta_t for x in range(0,samples + 1)]
time_steps = []

for timeStep in time[1:]:
    time_steps.append(timeStep)
    print('\ntimeStep = ', timeStep)
          
    with suppress(Exception):
        solve_me_model(model, 1.0, min_mu = .01, precision=1e-2, using_soplex=False)
        solution_results.append(model.solution.f)

    try:
        mu = model.solution.f
    except:
        mu = 0.00001
        
    mu_results.append(mu)
    if mu <= 0:
        mu = 0.00001
    print('mu = ', mu)
    
    # Calculate accumulated biomass
    biomass.append(biomass_t)
    biomass_t = biomass_0*exp(mu*delta_t);
    biomass_0 = biomass_t
    
    # Calculate glucose concentration in extracellular medium
    try:
        flux_uptake = model.reactions.EX_glc__D_e.x
    except:
        flux_uptake = 0
        
    glc_concentration = glc_past_concentration - (flux_uptake/mu) * biomass_t * (1 - exp(mu*delta_t))
    
    if glc_concentration <= 0: 
        glc_concentration = 0
        model.reactions.EX_glc__D_e.lower_bound = 0

    glucose_concentration.append(glc_concentration)
    glc_past_concentration = glc_concentration
    
    # Acetate concentration
    try:
        flux_uptake = model.reactions.EX_ac_e.x
    except:
        flux_uptake = 0

    ac_concentration = ac_past_concentration - (flux_uptake/mu) * biomass_t * (1 - exp(mu*delta_t))

    if ac_concentration <= 0: 
        ac_concentration = 0
        model.reactions.EX_ac_e.lower_bound = 0

    acetate_concentration.append(ac_concentration)
    ac_past_concentration = ac_concentration    

    # Formate concentration
    try:
        flux_uptake = model.reactions.EX_for_e.x
    except:
        flux_uptake = 0

    for_concentration = for_past_concentration - (flux_uptake/mu) * biomass_t * (1 - exp(mu*delta_t))

    if for_concentration <= 0: 
        for_concentration = 0
        model.reactions.EX_for_e.lower_bound = 0

    formate_concentration.append(for_concentration)
    for_past_concentration = for_concentration
# Out:
# timeStep =  0.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 34.528003 seconds
# Finished substituting S,lb,ub in 2.406856 seconds
# Finished makeME_LP in 0.374292 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.335075 seconds
# Finished makeME_LP in 0.368807 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.75 0.75 1.0 0.75 optimal
# Finished substituting S,lb,ub in 2.359871 seconds
# Finished makeME_LP in 0.384538 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.75 0.75 0.875 0.875 1
# Finished substituting S,lb,ub in 2.365128 seconds
# Finished makeME_LP in 0.375088 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.8125 0.8125 0.875 0.8125 optimal
# Finished substituting S,lb,ub in 2.370758 seconds
# Finished makeME_LP in 0.375321 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.8125 0.8125 0.84375 0.84375 1
# Finished substituting S,lb,ub in 2.360844 seconds
# Finished makeME_LP in 0.369732 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.828125 0.828125 0.84375 0.828125 optimal
# Finished substituting S,lb,ub in 2.346344 seconds
# Finished makeME_LP in 0.374072 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.828125 0.828125 0.8359375 0.8359375 1
# Bisection done in 119.326 seconds
# mu =  0.828125
#
# timeStep =  1.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 34.098707 seconds
# Finished substituting S,lb,ub in 2.394743 seconds
# Finished makeME_LP in 0.374338 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.375792 seconds
# Finished makeME_LP in 0.379164 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.75 0.75 1.0 0.75 optimal
# Finished substituting S,lb,ub in 2.443383 seconds
# Finished makeME_LP in 0.380078 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.75 0.75 0.875 0.875 1
# Finished substituting S,lb,ub in 2.436760 seconds
# Finished makeME_LP in 0.377438 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.8125 0.8125 0.875 0.8125 optimal
# Finished substituting S,lb,ub in 2.396325 seconds
# Finished makeME_LP in 0.391850 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.8125 0.8125 0.84375 0.84375 1
# Finished substituting S,lb,ub in 2.409257 seconds
# Finished makeME_LP in 0.376181 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.828125 0.828125 0.84375 0.828125 optimal
# Finished substituting S,lb,ub in 2.409367 seconds
# Finished makeME_LP in 0.380052 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.828125 0.828125 0.8359375 0.8359375 1
# Bisection done in 124.04 seconds
# mu =  0.828125
#
# timeStep =  1.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 34.549285 seconds
# Finished substituting S,lb,ub in 2.355531 seconds
# Finished makeME_LP in 0.382377 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.368587 seconds
# Finished makeME_LP in 0.383571 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.75 0.75 1.0 0.75 optimal
# Finished substituting S,lb,ub in 2.391876 seconds
# Finished makeME_LP in 0.385548 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.75 0.75 0.875 0.875 1
# Finished substituting S,lb,ub in 2.390914 seconds
# Finished makeME_LP in 0.380072 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.8125 0.8125 0.875 0.8125 optimal
# Finished substituting S,lb,ub in 2.399273 seconds
# Finished makeME_LP in 0.383314 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.8125 0.8125 0.84375 0.84375 1
# Finished substituting S,lb,ub in 2.421761 seconds
# Finished makeME_LP in 0.377274 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.828125 0.828125 0.84375 0.828125 optimal
# Finished substituting S,lb,ub in 2.379125 seconds
# Finished makeME_LP in 0.385624 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.828125 0.828125 0.8359375 0.8359375 1
# Bisection done in 124.309 seconds
# mu =  0.828125
#
# timeStep =  2.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 34.029130 seconds
# Finished substituting S,lb,ub in 2.380438 seconds
# Finished makeME_LP in 0.370011 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.365832 seconds
# Finished makeME_LP in 0.373925 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.75 0.75 1.0 0.75 optimal
# Finished substituting S,lb,ub in 2.365871 seconds
# Finished makeME_LP in 0.370091 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.75 0.75 0.875 0.875 1
# Finished substituting S,lb,ub in 2.368572 seconds
# Finished makeME_LP in 0.368608 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.8125 0.8125 0.875 0.8125 optimal
# Finished substituting S,lb,ub in 2.356998 seconds
# Finished makeME_LP in 0.370886 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.8125 0.8125 0.84375 0.84375 1
# Finished substituting S,lb,ub in 2.379251 seconds
# Finished makeME_LP in 0.384437 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.828125 0.828125 0.84375 0.828125 optimal
# Finished substituting S,lb,ub in 2.411010 seconds
# Finished makeME_LP in 0.373857 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.828125 0.828125 0.8359375 0.8359375 1
# Bisection done in 123.322 seconds
# mu =  0.828125
#
# timeStep =  2.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 33.708006 seconds
# Finished substituting S,lb,ub in 2.331007 seconds
# Finished makeME_LP in 0.375692 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.356710 seconds
# Finished makeME_LP in 0.375995 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.75 0.75 1.0 0.75 optimal
# Finished substituting S,lb,ub in 2.432035 seconds
# Finished makeME_LP in 0.382511 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.75 0.75 0.875 0.875 1
# Finished substituting S,lb,ub in 2.395708 seconds
# Finished makeME_LP in 0.380930 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.8125 0.8125 0.875 0.8125 optimal
# Finished substituting S,lb,ub in 2.389340 seconds
# Finished makeME_LP in 0.372847 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.8125 0.8125 0.84375 0.84375 1
# Finished substituting S,lb,ub in 2.407317 seconds
# Finished makeME_LP in 0.382096 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.828125 0.828125 0.84375 0.828125 optimal
# Finished substituting S,lb,ub in 2.421266 seconds
# Finished makeME_LP in 0.383050 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.828125 0.828125 0.8359375 0.8359375 1
# Bisection done in 123.104 seconds
# mu =  0.828125
#
# timeStep =  3.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 34.057440 seconds
# Finished substituting S,lb,ub in 2.331745 seconds
# Finished makeME_LP in 0.369270 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.364492 seconds
# Finished makeME_LP in 0.382334 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.75 0.75 1.0 0.75 optimal
# Finished substituting S,lb,ub in 2.441892 seconds
# Finished makeME_LP in 0.381910 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.75 0.75 0.875 0.875 1
# Finished substituting S,lb,ub in 2.385517 seconds
# Finished makeME_LP in 0.381922 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.8125 0.8125 0.875 0.8125 optimal
# Finished substituting S,lb,ub in 2.398864 seconds
# Finished makeME_LP in 0.388943 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.8125 0.8125 0.84375 0.84375 1
# Finished substituting S,lb,ub in 2.405143 seconds
# Finished makeME_LP in 0.379193 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.828125 0.828125 0.84375 0.828125 optimal
# Finished substituting S,lb,ub in 2.356239 seconds
# Finished makeME_LP in 0.377783 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.828125 0.828125 0.8359375 0.8359375 1
# Bisection done in 123.163 seconds
# mu =  0.828125
#
# timeStep =  3.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 33.786329 seconds
# Finished substituting S,lb,ub in 2.350231 seconds
# Finished makeME_LP in 0.365143 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.345346 seconds
# Finished makeME_LP in 0.385278 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.75 0.75 1.0 0.75 optimal
# Finished substituting S,lb,ub in 2.406466 seconds
# Finished makeME_LP in 0.369090 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.75 0.75 0.875 0.875 1
# Finished substituting S,lb,ub in 2.388781 seconds
# Finished makeME_LP in 0.381436 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.8125 0.8125 0.875 0.8125 optimal
# Finished substituting S,lb,ub in 2.395360 seconds
# Finished makeME_LP in 0.382489 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.8125 0.8125 0.84375 0.84375 1
# Finished substituting S,lb,ub in 2.378577 seconds
# Finished makeME_LP in 0.389891 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.828125 0.828125 0.84375 0.828125 optimal
# Finished substituting S,lb,ub in 2.429025 seconds
# Finished makeME_LP in 0.376750 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.828125 0.828125 0.8359375 0.8359375 1
# Bisection done in 122.988 seconds
# mu =  0.828125
#
# timeStep =  4.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 33.486429 seconds
# Finished substituting S,lb,ub in 2.355767 seconds
# Finished makeME_LP in 0.378817 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.370365 seconds
# Finished makeME_LP in 0.374703 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.328841 seconds
# Finished makeME_LP in 0.369216 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.125 0.125 0.25 0.125 optimal
# Finished substituting S,lb,ub in 2.324173 seconds
# Finished makeME_LP in 0.375130 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.1875 0.1875 0.25 0.1875 optimal
# Finished substituting S,lb,ub in 2.364111 seconds
# Finished makeME_LP in 0.372154 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.21875 0.21875 0.25 0.21875 optimal
# Finished substituting S,lb,ub in 2.339757 seconds
# Finished makeME_LP in 0.369345 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.234375 0.234375 0.25 0.234375 optimal
# Finished substituting S,lb,ub in 2.323044 seconds
# Finished makeME_LP in 0.374476 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.234375 0.234375 0.2421875 0.2421875 1
# Bisection done in 311.308 seconds
# mu =  0.234375
#
# timeStep =  4.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.630469 seconds
# Finished substituting S,lb,ub in 2.257329 seconds
# Finished makeME_LP in 0.364382 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.293710 seconds
# Finished makeME_LP in 0.371021 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.443722 seconds
# Finished makeME_LP in 0.374966 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.482243 seconds
# Finished makeME_LP in 0.383941 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.357177 seconds
# Finished makeME_LP in 0.380128 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.389338 seconds
# Finished makeME_LP in 0.377417 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.449047 seconds
# Finished makeME_LP in 0.385509 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0 0.0 0.0078125 0.0078125 1
# Bisection done in 649.828 seconds
# mu =  1e-05
#
# timeStep =  5.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 33.216735 seconds
# Finished substituting S,lb,ub in 2.343079 seconds
# Finished makeME_LP in 0.372160 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.331336 seconds
# Finished makeME_LP in 0.367522 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.377198 seconds
# Finished makeME_LP in 0.369901 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.582145 seconds
# Finished makeME_LP in 0.393577 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.345948 seconds
# Finished makeME_LP in 0.372889 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.370723 seconds
# Finished makeME_LP in 0.368877 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.362200 seconds
# Finished makeME_LP in 0.378477 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0 0.0 0.0078125 0.0078125 1
# Bisection done in 645.107 seconds
# mu =  1e-05
#
# timeStep =  5.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 33.584754 seconds
# Finished substituting S,lb,ub in 2.265379 seconds
# Finished makeME_LP in 0.372247 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.451854 seconds
# Finished makeME_LP in 0.386251 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.406239 seconds
# Finished makeME_LP in 0.417613 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.345312 seconds
# Finished makeME_LP in 0.364801 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.304824 seconds
# Finished makeME_LP in 0.375688 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.453270 seconds
# Finished makeME_LP in 0.397793 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.375643 seconds
# Finished makeME_LP in 0.380044 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0 0.0 0.0078125 0.0078125 1
# Bisection done in 638.401 seconds
# mu =  1e-05
#
# timeStep =  6.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 33.668870 seconds
# Finished substituting S,lb,ub in 2.375760 seconds
# Finished makeME_LP in 0.380392 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.389769 seconds
# Finished makeME_LP in 0.371455 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.385771 seconds
# Finished makeME_LP in 0.365814 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.246255 seconds
# Finished makeME_LP in 0.359580 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.206374 seconds
# Finished makeME_LP in 0.360724 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.211406 seconds
# Finished makeME_LP in 0.363350 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.233371 seconds
# Finished makeME_LP in 0.358192 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0 0.0 0.0078125 0.0078125 1
# Bisection done in 629.015 seconds
# mu =  1e-05
#
# timeStep =  6.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.140109 seconds
# Finished substituting S,lb,ub in 2.227819 seconds
# Finished makeME_LP in 0.363759 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.231138 seconds
# Finished makeME_LP in 0.362253 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.219723 seconds
# Finished makeME_LP in 0.361746 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.209579 seconds
# Finished makeME_LP in 0.358500 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.201171 seconds
# Finished makeME_LP in 0.360127 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.239160 seconds
# Finished makeME_LP in 0.363144 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.225854 seconds
# Finished makeME_LP in 0.367203 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0 0.0 0.0078125 0.0078125 1
# Bisection done in 616.313 seconds
# mu =  1e-05
#
# timeStep =  7.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.032163 seconds
# Finished substituting S,lb,ub in 2.238383 seconds
# Finished makeME_LP in 0.367245 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.271252 seconds
# Finished makeME_LP in 0.366450 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.218205 seconds
# Finished makeME_LP in 0.360489 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.205505 seconds
# Finished makeME_LP in 0.360626 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.226656 seconds
# Finished makeME_LP in 0.368270 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.200664 seconds
# Finished makeME_LP in 0.355594 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.242346 seconds
# Finished makeME_LP in 0.365667 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0 0.0 0.0078125 0.0078125 1
# Bisection done in 616.452 seconds
# mu =  1e-05
#
# timeStep =  7.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.029149 seconds
# Finished substituting S,lb,ub in 2.204903 seconds
# Finished makeME_LP in 0.355910 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.227852 seconds
# Finished makeME_LP in 0.364904 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.240086 seconds
# Finished makeME_LP in 0.367074 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.241112 seconds
# Finished makeME_LP in 0.369379 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.215205 seconds
# Finished makeME_LP in 0.357761 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.202418 seconds
# Finished makeME_LP in 0.360951 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.175181 seconds
# Finished makeME_LP in 0.364703 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0 0.0 0.0078125 0.0078125 1
# Bisection done in 616.702 seconds
# mu =  1e-05
#
# timeStep =  8.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.105032 seconds
# Finished substituting S,lb,ub in 2.226065 seconds
# Finished makeME_LP in 0.438108 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.275045 seconds
# Finished makeME_LP in 0.363497 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.224051 seconds
# Finished makeME_LP in 0.368715 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.219980 seconds
# Finished makeME_LP in 0.360134 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.190845 seconds
# Finished makeME_LP in 0.370335 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.206229 seconds
# Finished makeME_LP in 0.368439 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.221455 seconds
# Finished makeME_LP in 0.364331 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0 0.0 0.0078125 0.0078125 1
# Bisection done in 617.107 seconds
# mu =  1e-05

# %%
import matplotlib.pyplot as plt

times2 = [x/100 for x in range(0,100,1)]
x = time
y = glucose_concentration
  
# plotting the points 
plt.plot(x, glucose_concentration, label = "Glucose Concentration")
plt.plot(x, acetate_concentration, label = "Acetate Concentration")
plt.plot(x, formate_concentration, label = "Formate Concentration")

# naming the x axis
plt.xlabel('Time')
# naming the y axis
plt.ylabel('Glucose Concentration')
  
# giving a title to my graph
plt.title('Aerobic Glucose Concentration vs time')
  
# function to show the plot
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

times2 = [x/100 for x in range(0,500,5)]
x = time
y = biomass
  
# plotting the points 
plt.plot(x, y, label = "Time")

# naming the x axis
plt.xlabel('Time')
# naming the y axis
plt.ylabel('Biomass')
  
# giving a title to my graph
plt.title('Biomass vs time')
  
# function to show the plot
plt.show()

# %%
x1 = time[1:]
y = mu_results
  
# plotting the points 
plt.plot(x1, y, label = "Time")

# naming the x axis
plt.xlabel('Time')
# naming the y axis
plt.ylabel('Growth-rate')
  
# giving a title to my graph
plt.title('Growth-rate vs Time')
  
# function to show the plot
plt.show()
