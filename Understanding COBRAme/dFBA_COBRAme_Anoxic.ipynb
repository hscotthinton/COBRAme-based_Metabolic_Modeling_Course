# %% [markdown]
# # Anoxic Dynamic Flux Balance Analysis (dFBA) using COBRAme

# %%
import cobra
#from cobra.io import load_model
import numpy as np
#from tqdm import tqdm
from math import exp
from contextlib import suppress

from scipy.integrate import solve_ivp

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/solvers/__init__.py:63: UserWarning: No LP solvers found
#   warn("No LP solvers found")
# /usr/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/io/sbml3.py:24: UserWarning: Install lxml for faster SBML I/O
#   warn("Install lxml for faster SBML I/O")
# /usr/lib/python3.6/site-packages/cobra-0.5.11-py3.6-linux-x86_64.egg/cobra/io/__init__.py:12: UserWarning: cobra.io.sbml requires libsbml
#   warn("cobra.io.sbml requires libsbml")

# %%
from __future__ import print_function, division, absolute_import

# python imports
import re
from os.path import join
from collections import defaultdict
import pickle
import pandas as pd

# third party imports
import pandas
import tabulate
import cobra
pd.set_option('display.max_columns', 100)
pd.set_option('display.width',100)
pd.set_option('display.max_colwidth',300)

# ECOLIme
import ecolime
from ecolime import (transcription, translation, flat_files, generics, formulas, compartments)

# COBRAme
import cobrame
from cobrame.util import building, mu, me_model_interface
#from cobrame.io.json import save_json_me_model, save_reduced_json_me_model

# %% [markdown]
# Create or load a cobrapy model. Here, we use the 'textbook' e-coli core model.

# %%
with open('iJL1678b.pickle', 'rb') as f:
    model = pickle.load(f)

model.reactions.EX_glc__D_e.lower_bound = -10
model.reactions.EX_o2_e.lower_bound = -7
model.reactions.EX_ac_e.lower_bound = -10
model.reactions.EX_for_e.lower_bound = -10

# %%
def solve_me_model(model, max_mu, precision=1e-6, min_mu=0, using_soplex=False,
                  compiled_expressions=None):
    if using_soplex:
        from cobrame.solve.algorithms import binary_search
        binary_search(model, min_mu=min_mu, max_mu=max_mu, debug=True, mu_accuracy=precision,
                      compiled_expressions=compiled_expressions)
    else:
        from qminospy.me1 import ME_NLP1
        # The object containing solveME methods--composite that uses a ME model object 
        me_nlp = ME_NLP1(model, growth_key='mu')
        # Use bisection for now (until the NLP formulation is worked out)
        muopt, hs, xopt, cache = me_nlp.bisectmu(precision=precision, mumax=max_mu)
        model.solution.f = model.solution.x_dict['biomass_dilution']
        
def show_escher_map(model, solution=None):
    import escher
    view = escher.Builder("iJO1366.Central metabolism")
    view.reaction_data = model.get_metabolic_flux(solution=solution)
    return view

# %%
# Initial Constants
biomass_0 = 0.035 # Initial biomass
biomass_t = biomass_0
#delta_t = 0.25
time_total = 8 # Hours
samples = 16 # Total number of samples
delta_t = time_total/samples
biomass = []
mu_results = []
solution_results = []
biomass.append(biomass_0)

# Initialize glucose variables
glc_initial_concentration = 10
glc_past_concentration = glc_initial_concentration
glucose_concentration = []
glucose_concentration.append(glc_initial_concentration)

# Initialize acetate variables
ac_initial_concentration = 0
ac_past_concentration = ac_initial_concentration
acetate_concentration = []
acetate_concentration.append(ac_initial_concentration)

# Initialize formate variables
for_initial_concentration = 0
for_past_concentration = for_initial_concentration
formate_concentration = []
formate_concentration.append(for_initial_concentration)

# Set metabolite t0 concentrations
glc_concentration = glc_initial_concentration
ac_concentration = ac_initial_concentration
for_concentration = for_initial_concentration

# Determine timesteps
time = [x*delta_t for x in range(0,samples + 1)]
time_steps = []

for timeStep in time[1:]:
    time_steps.append(timeStep)
    print('\ntimeStep = ', timeStep)
          
    with suppress(Exception):
        solve_me_model(model, 1.0, min_mu = .01, precision=1e-2, using_soplex=False)
        solution_results.append(model.solution.f)

    try:
        mu = model.solution.f
    except:
        mu = 0.00001
        
    #mu_results.append(mu)
    if mu <= 0:
        mu = 0.00001
    print('mu = ', mu)
    
    mu_results.append(mu)
        
    # Calculate accumulated biomass
    biomass.append(biomass_t)
    biomass_t = biomass_0*exp(mu*delta_t);
    biomass_0 = biomass_t
    
    # Calculate glucose concentration in extracellular medium
    try:
        flux_uptake = model.reactions.EX_glc__D_e.x
    except:
        flux_uptake = 0
        
    glc_concentration = glc_past_concentration - (flux_uptake/mu) * biomass_t * (1 - exp(mu*delta_t))
    
    if glc_concentration <= 0: 
        glc_concentration = 0
        model.reactions.EX_glc__D_e.lower_bound = 0

    glucose_concentration.append(glc_concentration)
    glc_past_concentration = glc_concentration
    
    # Acetate concentration
    try:
        flux_uptake = model.reactions.EX_ac_e.x
    except:
        flux_uptake = 0

    ac_concentration = ac_past_concentration - (flux_uptake/mu) * biomass_t * (1 - exp(mu*delta_t))

    if ac_concentration <= 0: 
        ac_concentration = 0
        model.reactions.EX_ac_e.lower_bound = 0

    acetate_concentration.append(ac_concentration)
    ac_past_concentration = ac_concentration    

    # Formate concentration
    try:
        flux_uptake = model.reactions.EX_for_e.x
    except:
        flux_uptake = 0

    for_concentration = for_past_concentration - (flux_uptake/mu) * biomass_t * (1 - exp(mu*delta_t))

    if for_concentration <= 0: 
        for_concentration = 0
        model.reactions.EX_for_e.lower_bound = 0

    formate_concentration.append(for_concentration)
    for_past_concentration = for_concentration
# Out:
# timeStep =  0.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 33.605269 seconds
# Finished substituting S,lb,ub in 2.337991 seconds
# Finished makeME_LP in 0.375355 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.204155 seconds
# Finished makeME_LP in 0.358872 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.5 0.5 0.75 0.75 1
# Finished substituting S,lb,ub in 2.191154 seconds
# Finished makeME_LP in 0.358311 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.5 0.5 0.625 0.625 1
# Finished substituting S,lb,ub in 2.206393 seconds
# Finished makeME_LP in 0.362051 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.5625 0.5625 0.625 0.5625 optimal
# Finished substituting S,lb,ub in 2.205652 seconds
# Finished makeME_LP in 0.358791 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.59375 0.59375 0.625 0.59375 optimal
# Finished substituting S,lb,ub in 2.246367 seconds
# Finished makeME_LP in 0.362463 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.609375 0.609375 0.625 0.609375 optimal
# Finished substituting S,lb,ub in 2.199465 seconds
# Finished makeME_LP in 0.358875 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.6171875 0.6171875 0.625 0.6171875 optimal
# Bisection done in 132.063 seconds
# mu =  0.6171875
#
# timeStep =  1.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 31.720885 seconds
# Finished substituting S,lb,ub in 2.215758 seconds
# Finished makeME_LP in 0.365801 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.253321 seconds
# Finished makeME_LP in 0.365420 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.5 0.5 0.75 0.75 1
# Finished substituting S,lb,ub in 2.259678 seconds
# Finished makeME_LP in 0.362737 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.5 0.5 0.625 0.625 1
# Finished substituting S,lb,ub in 2.316549 seconds
# Finished makeME_LP in 0.369641 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.5625 0.5625 0.625 0.5625 optimal
# Finished substituting S,lb,ub in 2.272542 seconds
# Finished makeME_LP in 0.383049 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.59375 0.59375 0.625 0.59375 optimal
# Finished substituting S,lb,ub in 2.315316 seconds
# Finished makeME_LP in 0.380474 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.609375 0.609375 0.625 0.609375 optimal
# Finished substituting S,lb,ub in 2.278908 seconds
# Finished makeME_LP in 0.390871 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.6171875 0.6171875 0.625 0.6171875 optimal
# Bisection done in 129.975 seconds
# mu =  0.6171875
#
# timeStep =  1.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.528943 seconds
# Finished substituting S,lb,ub in 2.390150 seconds
# Finished makeME_LP in 0.363223 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.366069 seconds
# Finished makeME_LP in 0.397742 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.5 0.5 0.75 0.75 1
# Finished substituting S,lb,ub in 2.301454 seconds
# Finished makeME_LP in 0.376195 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.5 0.5 0.625 0.625 1
# Finished substituting S,lb,ub in 2.297181 seconds
# Finished makeME_LP in 0.408198 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.5625 0.5625 0.625 0.5625 optimal
# Finished substituting S,lb,ub in 2.447121 seconds
# Finished makeME_LP in 0.369000 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.59375 0.59375 0.625 0.59375 optimal
# Finished substituting S,lb,ub in 2.325737 seconds
# Finished makeME_LP in 0.364351 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.609375 0.609375 0.625 0.609375 optimal
# Finished substituting S,lb,ub in 2.253938 seconds
# Finished makeME_LP in 0.368037 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.6171875 0.6171875 0.625 0.6171875 optimal
# Bisection done in 131.662 seconds
# mu =  0.6171875
#
# timeStep =  2.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.194141 seconds
# Finished substituting S,lb,ub in 2.199832 seconds
# Finished makeME_LP in 0.356333 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.266390 seconds
# Finished makeME_LP in 0.389664 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.5 0.5 0.75 0.75 1
# Finished substituting S,lb,ub in 2.275335 seconds
# Finished makeME_LP in 0.362559 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.5 0.5 0.625 0.625 1
# Finished substituting S,lb,ub in 2.280082 seconds
# Finished makeME_LP in 0.363295 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.5625 0.5625 0.625 0.5625 optimal
# Finished substituting S,lb,ub in 2.283182 seconds
# Finished makeME_LP in 0.367541 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.59375 0.59375 0.625 0.59375 optimal
# Finished substituting S,lb,ub in 2.284884 seconds
# Finished makeME_LP in 0.384327 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.609375 0.609375 0.625 0.609375 optimal
# Finished substituting S,lb,ub in 2.230162 seconds
# Finished makeME_LP in 0.363425 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.6171875 0.6171875 0.625 0.6171875 optimal
# Bisection done in 129.678 seconds
# mu =  0.6171875
#
# timeStep =  2.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 31.927604 seconds
# Finished substituting S,lb,ub in 2.205918 seconds
# Finished makeME_LP in 0.356612 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.268927 seconds
# Finished makeME_LP in 0.372962 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.5 0.5 0.75 0.75 1
# Finished substituting S,lb,ub in 2.643901 seconds
# Finished makeME_LP in 0.386073 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.5 0.5 0.625 0.625 1
# Finished substituting S,lb,ub in 2.368481 seconds
# Finished makeME_LP in 0.357965 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.5625 0.5625 0.625 0.5625 optimal
# Finished substituting S,lb,ub in 2.410722 seconds
# Finished makeME_LP in 0.364749 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.59375 0.59375 0.625 0.59375 optimal
# Finished substituting S,lb,ub in 2.309692 seconds
# Finished makeME_LP in 0.362562 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.609375 0.609375 0.625 0.609375 optimal
# Finished substituting S,lb,ub in 2.288583 seconds
# Finished makeME_LP in 0.364320 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.6171875 0.6171875 0.625 0.6171875 optimal
# Bisection done in 130.184 seconds
# mu =  0.6171875
#
# timeStep =  3.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 31.784063 seconds
# Finished substituting S,lb,ub in 2.188376 seconds
# Finished makeME_LP in 0.358572 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.221628 seconds
# Finished makeME_LP in 0.360506 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.5 0.5 0.75 0.75 1
# Finished substituting S,lb,ub in 2.212327 seconds
# Finished makeME_LP in 0.363604 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.5 0.5 0.625 0.625 1
# Finished substituting S,lb,ub in 2.224544 seconds
# Finished makeME_LP in 0.364630 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.5625 0.5625 0.625 0.5625 optimal
# Finished substituting S,lb,ub in 2.226470 seconds
# Finished makeME_LP in 0.362120 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.59375 0.59375 0.625 0.59375 optimal
# Finished substituting S,lb,ub in 2.255004 seconds
# Finished makeME_LP in 0.365407 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.609375 0.609375 0.625 0.609375 optimal
# Finished substituting S,lb,ub in 2.218442 seconds
# Finished makeME_LP in 0.360253 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.6171875 0.6171875 0.625 0.6171875 optimal
# Bisection done in 128.443 seconds
# mu =  0.6171875
#
# timeStep =  3.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.064785 seconds
# Finished substituting S,lb,ub in 2.295782 seconds
# Finished makeME_LP in 0.359289 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.261983 seconds
# Finished makeME_LP in 0.358722 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.5 0.5 0.75 0.75 1
# Finished substituting S,lb,ub in 2.246200 seconds
# Finished makeME_LP in 0.361035 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.5 0.5 0.625 0.625 1
# Finished substituting S,lb,ub in 2.262636 seconds
# Finished makeME_LP in 0.358771 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.5625 0.5625 0.625 0.5625 optimal
# Finished substituting S,lb,ub in 2.231964 seconds
# Finished makeME_LP in 0.358875 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.59375 0.59375 0.625 0.59375 optimal
# Finished substituting S,lb,ub in 2.233432 seconds
# Finished makeME_LP in 0.358963 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.609375 0.609375 0.625 0.609375 optimal
# Finished substituting S,lb,ub in 2.217319 seconds
# Finished makeME_LP in 0.362495 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.6171875 0.6171875 0.625 0.6171875 optimal
# Bisection done in 129.153 seconds
# mu =  0.6171875
#
# timeStep =  4.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 31.605537 seconds
# Finished substituting S,lb,ub in 2.200498 seconds
# Finished makeME_LP in 0.358299 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.263957 seconds
# Finished makeME_LP in 0.364706 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.5 0.5 0.75 0.75 1
# Finished substituting S,lb,ub in 2.287044 seconds
# Finished makeME_LP in 0.357605 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.5 0.5 0.625 0.625 1
# Finished substituting S,lb,ub in 2.247150 seconds
# Finished makeME_LP in 0.363199 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.5625 0.5625 0.625 0.5625 optimal
# Finished substituting S,lb,ub in 2.261432 seconds
# Finished makeME_LP in 0.363717 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.59375 0.59375 0.625 0.59375 optimal
# Finished substituting S,lb,ub in 2.258268 seconds
# Finished makeME_LP in 0.364597 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.609375 0.609375 0.625 0.609375 optimal
# Finished substituting S,lb,ub in 2.220054 seconds
# Finished makeME_LP in 0.363831 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.6171875 0.6171875 0.625 0.6171875 optimal
# Bisection done in 128.558 seconds
# mu =  0.6171875
#
# timeStep =  4.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 31.764675 seconds
# Finished substituting S,lb,ub in 2.202382 seconds
# Finished makeME_LP in 0.357353 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.5 0.5 1.0 0.5 optimal
# Finished substituting S,lb,ub in 2.248297 seconds
# Finished makeME_LP in 0.374350 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.5 0.5 0.75 0.75 1
# Finished substituting S,lb,ub in 2.265889 seconds
# Finished makeME_LP in 0.361876 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.5 0.5 0.625 0.625 1
# Finished substituting S,lb,ub in 2.258778 seconds
# Finished makeME_LP in 0.361035 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.5625 0.5625 0.625 0.5625 optimal
# Finished substituting S,lb,ub in 2.257744 seconds
# Finished makeME_LP in 0.358449 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.59375 0.59375 0.625 0.59375 optimal
# Finished substituting S,lb,ub in 2.249330 seconds
# Finished makeME_LP in 0.365753 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.609375 0.609375 0.625 0.609375 optimal
# Finished substituting S,lb,ub in 2.255294 seconds
# Finished makeME_LP in 0.365674 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.6171875 0.6171875 0.625 0.6171875 optimal
# Bisection done in 128.816 seconds
# mu =  0.6171875
#
# timeStep =  5.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 31.925878 seconds
# Finished substituting S,lb,ub in 2.195329 seconds
# Finished makeME_LP in 0.357573 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.226398 seconds
# Finished makeME_LP in 0.369017 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.220040 seconds
# Finished makeME_LP in 0.362070 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.125 0.125 0.25 0.125 optimal
# Finished substituting S,lb,ub in 2.318183 seconds
# Finished makeME_LP in 0.392628 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.1875 0.1875 0.25 0.1875 optimal
# Finished substituting S,lb,ub in 2.311656 seconds
# Finished makeME_LP in 0.396935 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.1875 0.1875 0.21875 0.21875 1
# Finished substituting S,lb,ub in 2.270496 seconds
# Finished makeME_LP in 0.386621 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.203125 0.203125 0.21875 0.203125 optimal
# Finished substituting S,lb,ub in 2.274601 seconds
# Finished makeME_LP in 0.367785 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.2109375 0.2109375 0.21875 0.2109375 optimal
# Bisection done in 276.939 seconds
# mu =  0.2109375
#
# timeStep =  5.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.784930 seconds
# Finished substituting S,lb,ub in 2.277061 seconds
# Finished makeME_LP in 0.360283 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.272385 seconds
# Finished makeME_LP in 0.382967 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.294876 seconds
# Finished makeME_LP in 0.393897 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.125 0.125 0.25 0.125 optimal
# Finished substituting S,lb,ub in 2.280823 seconds
# Finished makeME_LP in 0.380686 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.1875 0.1875 0.25 0.1875 optimal
# Finished substituting S,lb,ub in 2.279279 seconds
# Finished makeME_LP in 0.365118 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.1875 0.1875 0.21875 0.21875 1
# Finished substituting S,lb,ub in 2.278796 seconds
# Finished makeME_LP in 0.363770 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.203125 0.203125 0.21875 0.203125 optimal
# Finished substituting S,lb,ub in 2.323031 seconds
# Finished makeME_LP in 0.389611 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.2109375 0.2109375 0.21875 0.2109375 optimal
# Bisection done in 279.793 seconds
# mu =  0.2109375
#
# timeStep =  6.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.694701 seconds
# Finished substituting S,lb,ub in 2.229857 seconds
# Finished makeME_LP in 0.363296 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.250582 seconds
# Finished makeME_LP in 0.364563 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.294435 seconds
# Finished makeME_LP in 0.385849 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.125 0.125 0.25 0.125 optimal
# Finished substituting S,lb,ub in 2.226304 seconds
# Finished makeME_LP in 0.366502 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.1875 0.1875 0.25 0.1875 optimal
# Finished substituting S,lb,ub in 2.254511 seconds
# Finished makeME_LP in 0.380743 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.1875 0.1875 0.21875 0.21875 1
# Finished substituting S,lb,ub in 2.270231 seconds
# Finished makeME_LP in 0.383584 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.203125 0.203125 0.21875 0.203125 optimal
# Finished substituting S,lb,ub in 2.264160 seconds
# Finished makeME_LP in 0.365125 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.2109375 0.2109375 0.21875 0.2109375 optimal
# Bisection done in 280.182 seconds
# mu =  0.2109375
#
# timeStep =  6.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.227382 seconds
# Finished substituting S,lb,ub in 2.281767 seconds
# Finished makeME_LP in 0.364517 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.248983 seconds
# Finished makeME_LP in 0.386354 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.271566 seconds
# Finished makeME_LP in 0.362169 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.262066 seconds
# Finished makeME_LP in 0.368600 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.244409 seconds
# Finished makeME_LP in 0.361591 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.280134 seconds
# Finished makeME_LP in 0.389296 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.252311 seconds
# Finished makeME_LP in 0.372790 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0078125 0.0078125 0.015625 0.0078125 optimal
# Bisection done in 626.764 seconds
# mu =  0.0078125
#
# timeStep =  7.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.167573 seconds
# Finished substituting S,lb,ub in 2.241319 seconds
# Finished makeME_LP in 0.361496 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.265634 seconds
# Finished makeME_LP in 0.387081 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.301314 seconds
# Finished makeME_LP in 0.385079 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.229006 seconds
# Finished makeME_LP in 0.376428 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.239013 seconds
# Finished makeME_LP in 0.378894 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.290035 seconds
# Finished makeME_LP in 0.380157 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.241209 seconds
# Finished makeME_LP in 0.379439 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0078125 0.0078125 0.015625 0.0078125 optimal
# Bisection done in 623.185 seconds
# mu =  0.0078125
#
# timeStep =  7.5
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 31.857419 seconds
# Finished substituting S,lb,ub in 2.196788 seconds
# Finished makeME_LP in 0.358906 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.299461 seconds
# Finished makeME_LP in 0.367540 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.296281 seconds
# Finished makeME_LP in 0.363219 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.359594 seconds
# Finished makeME_LP in 0.362856 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.226632 seconds
# Finished makeME_LP in 0.362156 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.574437 seconds
# Finished makeME_LP in 0.364446 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.321341 seconds
# Finished makeME_LP in 0.364364 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0078125 0.0078125 0.015625 0.0078125 optimal
# Bisection done in 621.537 seconds
# mu =  0.0078125
#
# timeStep =  8.0
# iter	muopt    	a     	b     	mu1       	stat1
# Finished compiling expressions in 32.048795 seconds
# Finished substituting S,lb,ub in 2.236001 seconds
# Finished makeME_LP in 0.357442 seconds
# Getting MINOS parameters from ME_NLP...
# 1 0.0 0.0 0.5 0.5 1
# Finished substituting S,lb,ub in 2.267121 seconds
# Finished makeME_LP in 0.361724 seconds
# Getting MINOS parameters from ME_NLP...
# 2 0.0 0.0 0.25 0.25 1
# Finished substituting S,lb,ub in 2.298997 seconds
# Finished makeME_LP in 0.364705 seconds
# Getting MINOS parameters from ME_NLP...
# 3 0.0 0.0 0.125 0.125 1
# Finished substituting S,lb,ub in 2.236874 seconds
# Finished makeME_LP in 0.384442 seconds
# Getting MINOS parameters from ME_NLP...
# 4 0.0 0.0 0.0625 0.0625 1
# Finished substituting S,lb,ub in 2.239187 seconds
# Finished makeME_LP in 0.389908 seconds
# Getting MINOS parameters from ME_NLP...
# 5 0.0 0.0 0.03125 0.03125 1
# Finished substituting S,lb,ub in 2.247566 seconds
# Finished makeME_LP in 0.363641 seconds
# Getting MINOS parameters from ME_NLP...
# 6 0.0 0.0 0.015625 0.015625 1
# Finished substituting S,lb,ub in 2.221724 seconds
# Finished makeME_LP in 0.364723 seconds
# Getting MINOS parameters from ME_NLP...
# 7 0.0 0.0 0.0078125 0.0078125 1
# Bisection done in 610.092 seconds
# mu =  1e-05

# %%
import matplotlib.pyplot as plt

times2 = [x/100 for x in range(0,100,1)]
x = time
y = glucose_concentration
  
# plotting the points 
plt.plot(x, glucose_concentration, label = "Glucose Concentration")
plt.plot(x, acetate_concentration, label = "Acetate Concentration")
plt.plot(x, formate_concentration, label = "Formate Concentration")

# naming the x axis
plt.xlabel('Time')
# naming the y axis
plt.ylabel('Glucose Concentration')
  
# giving a title to my graph
plt.title('Anoxic Glucose Concentration vs Time')
  
# function to show the plot
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

times2 = [x/100 for x in range(0,500,5)]
x = time
y = biomass
  
# plotting the points 
plt.plot(x, y, label = "Time")

# naming the x axis
plt.xlabel('Time')
# naming the y axis
plt.ylabel('Biomass')
  
# giving a title to my graph
plt.title('Biomass vs Time')
  
# function to show the plot
plt.show()

# %%
x1 = time[1:]
y = mu_results
  
# plotting the points 
plt.plot(x1, y, label = "Time")

# naming the x axis
plt.xlabel('Time')
# naming the y axis
plt.ylabel('Growth-rate')
  
# giving a title to my graph
plt.title('Growth-rate vs Time')
  
# function to show the plot
plt.show()
